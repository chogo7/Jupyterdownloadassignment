# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# # In this notebook, Data Science Tools and Ecosystems are summarized.

# %% [markdown]
# # Some of the popular languages that Data Sceintists use are:
# 1. R
# 2. Python
# 3. Julia

# %% [markdown]
# #Some of the comonly used libraries used by Data Scientists include:
# 1. NumPy
# 2. SciPy
# 3. Pandas

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |Visual Studio|
# |Spyder|
# |PyCharm|

# %% [markdown]
# ### Below are a few examples of evaluation arihmetic expressions in Python

# %%
# This is a simple arithnetic expression to multiply then add integers
x=(3*4)+5
print(x)
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
y=200/60
print(y)
# Out:
# 3.3333333333333335

# %% [markdown]
# ###Objectives:
#
# -popular languages for Data Scientists
# -popular libraries for Data Scientists
# -markdowns in Python
# -tables in Python

# %% [markdown]
# ## Author
#  Jason Duronslet
